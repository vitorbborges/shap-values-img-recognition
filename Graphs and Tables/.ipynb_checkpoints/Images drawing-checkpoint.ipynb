# %%
import os
import numpy as np
import pandas as pd
import cv2
import shap
from keras.models import model_from_json
import random
import time
from IPython.display import clear_output
import shap
import matplotlib.pyplot as plt
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
# load json and create model
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d5f36d26a57d> in <module>
#       1 # load json and create model
# ----> 2 json_file = open('model.json', 'r')
#       3 loaded_model_json = json_file.read()
#       4 json_file.close()
#       5 loaded_model = model_from_json(loaded_model_json)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.json'

# %%
shap_table = pd.read_csv('shapley_values.csv')
shap_table = shap_table.set_index('file_name')
shap_table = shap_table.sort_values(by=['shap_value'], ascending = True)

extrem30 = pd.concat([shap_table.head(15), shap_table.tail(15)])

# %%
my_dpi = 72
plt.rcParams["figure.figsize"] = (1800/my_dpi,450/my_dpi)

# %%
model_results_a = {
    '0%': [0.5, 0.7077435851097107, 0.4908173084259033,0.6300420761108398],
    '5%': [0.47887325286865234, 0.6984180212020874, 0.5047979950904846, 0.7725141644477844],
    '10%': [0.5, 0.6934801340103149, 0.504517138004303, 0.9068313837051392],
    '15%': [0.4960629940032959, 0.6944357752799988, 0.5029208660125732, 0.810606062412262],
    '20%': [0.44999998807907104, 0.6983855366706848, 0.5072939991950989, 0.8505346179008484],
    '25%': [0.4866071343421936, 0.7005838751792908, 0.5132785439491272, 0.7235099673271179],
    '30%': [0.5095238089561462, 0.7018591165542603, 0.5138929486274719, 0.8589075803756714],
    '35%': [0.5051546096801758, 0.6892727017402649, 0.5257683396339417, 0.8040348887443542],
    '40%': [0.5, 0.722040057182312, 0.5269800424575806, 0.8415820002555847],
    '45%': [0.5, 0.6960219144821167, 0.5214219093322754, 0.8649547696113586],
    '50%': [0.5133333206176758, 0.7007553577423096, 0.5361457467079163, 0.9041101336479187]
}

# %%
df = pd.DataFrame(model_results_a, index = ['Accuracy', 'Loss', 'Precision', 'Recall']).T

# %%
model_results_a = {
    '0%': [0.5, 0.7077435851097107, 0.4908173084259033,0.6300420761108398],
    '5%': [0.47887325286865234, 0.6984180212020874, 0.5047979950904846, 0.7725141644477844],
    '10%': [0.5, 0.6934801340103149, 0.504517138004303, 0.9068313837051392],
    '15%': [0.4960629940032959, 0.6944357752799988, 0.5029208660125732, 0.810606062412262],
    '20%': [0.44999998807907104, 0.6983855366706848, 0.5072939991950989, 0.8505346179008484],
    '25%': [0.4866071343421936, 0.7005838751792908, 0.5132785439491272, 0.7235099673271179],
    '30%': [0.5095238089561462, 0.7018591165542603, 0.5138929486274719, 0.8589075803756714],
    '35%': [0.5051546096801758, 0.6892727017402649, 0.5257683396339417, 0.8040348887443542],
    '40%': [0.5, 0.722040057182312, 0.5269800424575806, 0.8415820002555847],
    '45%': [0.5, 0.6960219144821167, 0.5214219093322754, 0.8649547696113586],
    '50%': [0.5133333206176758, 0.7007553577423096, 0.5361457467079163, 0.9041101336479187]
}

df = pd.DataFrame(model_results_a, index = ['Accuracy', 'Loss', 'Precision', 'Recall']).T

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)

ax1.plot(df['Accuracy'], linewidth = 3, ls = '--')
ax2.plot(df['Precision'], linewidth = 3, ls = '--')
ax3.plot(df['Recall'], linewidth = 3, ls = '--')
ax4.plot(df['Loss'], linewidth = 3, ls = '--')

ax1.set_title('Acurácia', fontsize = 15)
ax1.set_xlabel('Fração de dados de treino removida (%)', fontsize = 15)
ax1.set_ylabel('Acurácia do modelo (%)', fontsize = 15)

ax2.set_title('Precisão', fontsize = 15)
ax2.set_xlabel('Fração de dados de treino removida (%)', fontsize = 15)
ax2.set_ylabel('Precisão do modelo (%)', fontsize = 15)

ax3.set_title('Recall', fontsize = 15)
ax3.set_xlabel('Fração de dados de treino removida (%)', fontsize = 15)
ax3.set_ylabel('"Recall" do modelo (%)', fontsize = 15)

ax4.set_title('Função Perda', fontsize = 15)
ax4.set_xlabel('Fração de dados de treino removida (%)', fontsize = 15)
ax4.set_ylabel('Função Perda do modelo (%)', fontsize = 15)

fig.suptitle('Removendo dados de baixa qualidade', fontsize = 25)

fig.savefig('Removendo dados de baixa qualidade.png')

# %%
my_dpi = 72
plt.rcParams["figure.figsize"] = (1800/my_dpi,400/my_dpi)

model_results_d = {
    '0%': [0.5, 0.7077435851097107, 0.4908173084259033,0.6300420761108398],
    '5%': [0.4964788854122162, 0.6952239274978638,0.4871364235877991, 0.22519069910049438],
    '10%': [0.4703703820705414, 0.699339747428894, 0.4921876788139343, 0.4850202798843384],
    '15%': [0.4842519760131836, 0.6986483931541443, 0.48673179745674133, 0.16714252531528473],
    '20%': [0.47083333134651184, 0.6977912187576294, 0.47590261697769165, 0.1699436604976654],
    '25%': [0.5401785969734192, 0.6971460580825806, 0.5188260674476624, 0.2902138829231262],
    '30%': [0.5, 0.6940943598747253, 0.4712046980857849, 0.05181627348065376],
    '35%': [0.5051546096801758, 0.7207316160202026, 0.47087132930755615, 0.0777699202299118],
    '40%': [0.5, 0.7130273580551147 , 0.47826117277145386, 0.08159170299768448],
    '45%': [0.49390244483947754, 0.6968400478363037, 0.48755860328674316, 0.07737082242965698],
    '50%': [0.5, 0.7041274309158325, 0.31578925251960754, 0.015004432760179043]
}

df = pd.DataFrame(model_results_d, index = ['Accuracy', 'Loss', 'Precision', 'Recall']).T

fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)

ax1.plot(df['Accuracy'], linewidth = 3, ls = '--')
ax2.plot(df['Precision'], linewidth = 3, ls = '--')
ax3.plot(df['Recall'], linewidth = 3, ls = '--')
ax4.plot(df['Loss'], linewidth = 3, ls = '--')

ax1.set_title('Acurácia', fontsize = 15)
ax1.set_xlabel('Fração de dados de treino removida (%)', fontsize = 15)
ax1.set_ylabel('Acurácia do modelo (%)', fontsize = 15)

ax2.set_title('Precisão', fontsize = 15)
ax2.set_xlabel('Fração de dados de treino removida (%)', fontsize = 15)
ax2.set_ylabel('Precisão do modelo (%)', fontsize = 15)

ax3.set_title('Recall', fontsize = 15)
ax3.set_xlabel('Fração de dados de treino removida (%)', fontsize = 15)
ax3.set_ylabel('"Recall" do modelo (%)', fontsize = 15)

ax4.set_title('Função Perda', fontsize = 15)
ax4.set_xlabel('Fração de dados de treino removida (%)', fontsize = 15)
ax4.set_ylabel('Função Perda do modelo (%)', fontsize = 15)

fig.suptitle('Removendo dados de alta qualidade', fontsize = 25)

fig.savefig('Removendo dados de alta qualidade.png')

# %%
import statsmodels.api as sm

# %%
x = list(range(0,55, 5))
y = df['Loss']

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()

print(model.summary())
# Out:
# kurtosistest only valid for n>=20 ... continuing anyway, n=11
#                             OLS Regression Results
# ...
# Dep. Variable:                   Loss   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.095
# Method:                 Least Squares   F-statistic:                    0.1287
# Date:                Thu, 28 Oct 2021   Prob (F-statistic):              0.728
# Time:                        02:33:26   Log-Likelihood:                 37.169
# No. Observations:                  11   AIC:                            -70.34
# Df Residuals:                       9   BIC:                            -69.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
results_a = {
    'Accuracy': [0.234, 0.153],
    'Precision': [0.000, 0.896],
    'Recall': [0.070, 0.320],
    'Loss': [0.728, 0.014]
}

result_a_table = pd.DataFrame(results_a, index = ['p-value', 'R-squared'])
result_a_table.style.set_caption('Resultado das remoções de dados de baixa qualidade')
# Out:
# <style  type="text/css" >
# </style><table id="T_cffc9654_37b1_11ec_a8b0_5076af18dce6" ><caption>Resultado das remoções de dados de baixa qualidade</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >Precision</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Loss</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cffc9654_37b1_11ec_a8b0_5076af18dce6level0_row0" class="row_heading level0 row0" >p-value</th>
#                         <td id="T_cffc9654_37b1_11ec_a8b0_5076af18dce6row0_col0" class="data row0 col0" >0.234</td>
#                         <td id="T_cffc9654_37b1_11ec_a8b0_5076af18dce6row0_col1" class="data row0 col1" >0</td>
#                         <td id="T_cffc9654_37b1_11ec_a8b0_5076af18dce6row0_col2" class="data row0 col2" >0.07</td>
# ...

# %%
results_d = {
    'Accuracy': [0.477, 0.058],
    'Precision': [0.085, 0.293],
    'Recall': [0.003, 0.646],
    'Loss': [0.0456, 0.063]
}

result_d_table = pd.DataFrame(results_d, index = ['p-value', 'R-squared'])
result_d_table.style.set_caption('Resultado das remoções de dados de alta qualidade')
# Out:
# <style  type="text/css" >
# </style><table id="T_d28aa042_37b1_11ec_9349_5076af18dce6" ><caption>Resultado das remoções de dados de alta qualidade</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >Precision</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Loss</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d28aa042_37b1_11ec_9349_5076af18dce6level0_row0" class="row_heading level0 row0" >p-value</th>
#                         <td id="T_d28aa042_37b1_11ec_9349_5076af18dce6row0_col0" class="data row0 col0" >0.477</td>
#                         <td id="T_d28aa042_37b1_11ec_9349_5076af18dce6row0_col1" class="data row0 col1" >0.085</td>
#                         <td id="T_d28aa042_37b1_11ec_9349_5076af18dce6row0_col2" class="data row0 col2" >0.003</td>
# ...
